# %%
pip install tensorflow keras_cv
# Out:
# Requirement already satisfied: tensorflow in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (2.15.0)
# Collecting keras_cv
#   Obtaining dependency information for keras_cv from https://files.pythonhosted.org/packages/38/b2/8b1d8ee5e6f8ed5b190189c4b6699dda41a128c173d462de2e3594f512d8/keras_cv-0.8.2-py3-none-any.whl.metadata
#   Downloading keras_cv-0.8.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tensorflow-macos==2.15.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (4.25.2)
# Requirement already satisfied: setuptools in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: regex in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from keras_cv) (2022.7.9)
# Collecting tensorflow-datasets (from keras_cv)
#   Obtaining dependency information for tensorflow-datasets from https://files.pythonhosted.org/packages/fe/18/4865973f5469cfe33bbe1cfc2f1918335eb44f4cc3d316c1bce22c1af2bc/tensorflow_datasets-4.9.4-py3-none-any.whl.metadata
#   Using cached tensorflow_datasets-4.9.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting keras-core (from keras_cv)
#   Obtaining dependency information for keras-core from https://files.pythonhosted.org/packages/95/f7/b8dcff937ea64f822f0d3fe8c6010793406b82d14467cd0e9eecea458a40/keras_core-0.1.7-py3-none-any.whl.metadata
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Collecting kagglehub (from keras_cv)
#   Obtaining dependency information for kagglehub from https://files.pythonhosted.org/packages/47/b0/b0d3ddcb3e6357ed80c7000e4fac95a1bc8542d008627569ca4fb8f9d8b3/kagglehub-0.2.3-py3-none-any.whl.metadata
#   Downloading kagglehub-0.2.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: requests in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from kagglehub->keras_cv) (2.31.0)
# Requirement already satisfied: tqdm in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from kagglehub->keras_cv) (4.65.0)
# Collecting rich (from keras-core->keras_cv)
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras-core->keras_cv)
#   Obtaining dependency information for namex from https://files.pythonhosted.org/packages/73/59/7854fbfb59f8ae35483ce93493708be5942ebb6328cd85b3a609df629736/namex-0.0.8-py3-none-any.whl.metadata
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting dm-tree (from keras-core->keras_cv)
#   Obtaining dependency information for dm-tree from https://files.pythonhosted.org/packages/08/e2/4c29cb9876456517f21979ddcbb6048f28a3b52c61aa9d14d42adafcdca4/dm_tree-0.1.8-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached dm_tree-0.1.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.9 kB)
# Requirement already satisfied: click in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets->keras_cv) (8.0.4)
# Collecting etils[enp,epath,etree]>=0.9.0 (from tensorflow-datasets->keras_cv)
#   Obtaining dependency information for etils[enp,epath,etree]>=0.9.0 from https://files.pythonhosted.org/packages/d0/3c/784b5f94bcad62a4167f2347fe1095b627433c22a54aecc4504237494b81/etils-1.8.0-py3-none-any.whl.metadata
#   Using cached etils-1.8.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting promise (from tensorflow-datasets->keras_cv)
#   Using cached promise-2.3-py3-none-any.whl
# Requirement already satisfied: psutil in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets->keras_cv) (5.9.0)
# Collecting tensorflow-metadata (from tensorflow-datasets->keras_cv)
#   Obtaining dependency information for tensorflow-metadata from https://files.pythonhosted.org/packages/41/23/3705c7139886c079ef4c0e3be56a5a1fb90e9ee413a4b7caaee0ee0ea6fe/tensorflow_metadata-1.14.0-py3-none-any.whl.metadata
#   Using cached tensorflow_metadata-1.14.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: toml in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorflow-datasets->keras_cv) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: fsspec in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras_cv) (2024.3.1)
# Requirement already satisfied: importlib_resources in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras_cv) (6.4.0)
# Requirement already satisfied: zipp in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->keras_cv) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from requests->kagglehub->keras_cv) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from requests->kagglehub->keras_cv) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from requests->kagglehub->keras_cv) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from requests->kagglehub->keras_cv) (2023.7.22)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from rich->keras-core->keras_cv) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from rich->keras-core->keras_cv) (2.15.1)
# Collecting absl-py>=1.0.0 (from tensorflow-macos==2.15.0->tensorflow)
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/dd/87/de5c32fa1b1c6c3305d576e299801d8655c175ca9557019906247b994331/absl_py-1.4.0-py3-none-any.whl.metadata
#   Using cached absl_py-1.4.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting googleapis-common-protos<2,>=1.52.0 (from tensorflow-metadata->tensorflow-datasets->keras_cv)
#   Obtaining dependency information for googleapis-common-protos<2,>=1.52.0 from https://files.pythonhosted.org/packages/dc/a6/12a0c976140511d8bc8a16ad15793b2aef29ac927baa0786ccb7ddbb6e1c/googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata
#   Using cached googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-macos==2.15.0->tensorflow)
#   Obtaining dependency information for protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 from https://files.pythonhosted.org/packages/8d/14/619e24a4c70df2901e1f4dbc50a6291eb63a759172558df326347dce1f0d/protobuf-3.20.3-py2.py3-none-any.whl.metadata
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras_cv) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/sanikadhayabar/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.2.2)
# Downloading keras_cv-0.8.2-py3-none-any.whl (613 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 6.3 MB/s eta 0:00:00a 0:00:01
# Downloading kagglehub-0.2.3-py3-none-any.whl (33 kB)
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 24.0 MB/s eta 0:00:00a 0:00:01
# Using cached tensorflow_datasets-4.9.4-py3-none-any.whl (5.1 MB)
# Using cached dm_tree-0.1.8-cp311-cp311-macosx_11_0_arm64.whl (110 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 29.0 MB/s eta 0:00:00
# Downloading tensorflow_metadata-1.14.0-py3-none-any.whl (28 kB)
# Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 19.1 MB/s eta 0:00:00
# Using cached googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
# Using cached etils-1.8.0-py3-none-any.whl (156 kB)
# Installing collected packages: namex, dm-tree, protobuf, promise, etils, absl-py, rich, kagglehub, googleapis-common-protos, tensorflow-metadata, keras-core, tensorflow-datasets, keras_cv
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.2
#     Uninstalling protobuf-4.25.2:
#       Successfully uninstalled protobuf-4.25.2
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 2.1.0
#     Uninstalling absl-py-2.1.0:
#       Successfully uninstalled absl-py-2.1.0
# Successfully installed absl-py-1.4.0 dm-tree-0.1.8 etils-1.8.0 googleapis-common-protos-1.63.0 kagglehub-0.2.3 keras-core-0.1.7 keras_cv-0.8.2 namex-0.0.8 promise-2.3 protobuf-3.20.3 rich-13.7.1 tensorflow-datasets-4.9.4 tensorflow-metadata-1.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend

# %%
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
images = model.text_to_image("Huskies on the roof of a building, dancing tango", batch_size=3)

def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")

plot_images(images)
# Out:
# Downloading data from https://github.com/openai/CLIP/blob/main/clip/bpe_simple_vocab_16e6.txt.gz?raw=true
# 1356917/1356917 [==============================] - 1s 0us/step
# Downloading data from https://huggingface.co/fchollet/stable-diffusion/resolve/main/kcv_encoder.h5
# 492466864/492466864 [==============================] - 16s 0us/step
# WARNING:absl:XLA (`jit_compile`) is not yet supported on Apple M1/M2 ARM processors. Falling back to `jit_compile=False`.
# Downloading data from https://huggingface.co/fchollet/stable-diffusion/resolve/main/kcv_diffusion_model.h5
# 3439090152/3439090152 [==============================] - 131s 0us/step
# WARNING:absl:XLA (`jit_compile`) is not yet supported on Apple M1/M2 ARM processors. Falling back to `jit_compile=False`.
# 50/50 [==============================] - 1103s 18s/step
# Downloading data from https://huggingface.co/fchollet/stable-diffusion/resolve/main/kcv_decoder.h5
# 198180272/198180272 [==============================] - 4s 0us/step
# WARNING:absl:XLA (`jit_compile`) is not yet supported on Apple M1/M2 ARM processors. Falling back to `jit_compile=False`.
